# %% [markdown]
# ## sequence_list.csvの作成

# %%
import subprocess

result = subprocess.run(["ruby", "create_list.rb"], capture_output=True, text=True)
print(result.stdout)  # Rubyスクリプトの標準出力を表示

# エラー出力を表示
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR:

# %%
import pandas as pd

data_file = 'sequence_list.csv'

# %% [markdown]
# # フォルダ毎の数列の数

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] // 1000
df
# Out:
#       seq_no
# 0        100
# 1        100
# 2        100
# 3        100
# 4        100
# ...      ...
# 1081     199
# 1082     199
# 1083     199
# 1084     199
# 1085     199
#
# [1086 rows x 1 columns]

# %%
# show_rangeの開始に注意
show_range = list(range(99, 199+1))
df.plot.hist(bins=show_range)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# ヒストグラムの度数分布表を作成
hist = pd.cut(df['seq_no'], bins=show_range).value_counts().sort_index()

# 度数分布表を表示（ただし、度数が0は除く）
print('度数分布表')

cnt = 0
for i in hist.index:
    cnt += 1
    if i.right % 10 == 0:
        print()
    print(f'{i.right} : {hist[i]}', end=', ')

print()
print(f'合計 : {cnt}')
# Out:
# 度数分布表
#
# 100 : 18, 101 : 20, 102 : 10, 103 : 8, 104 : 17, 105 : 10, 106 : 12, 107 : 17, 108 : 25, 109 : 17,
# 110 : 6, 111 : 14, 112 : 24, 113 : 9, 114 : 13, 115 : 21, 116 : 12, 117 : 6, 118 : 10, 119 : 11,
# 120 : 18, 121 : 21, 122 : 11, 123 : 10, 124 : 6, 125 : 6, 126 : 20, 127 : 9, 128 : 10, 129 : 11,
# 130 : 6, 131 : 13, 132 : 14, 133 : 15, 134 : 6, 135 : 8, 136 : 5, 137 : 14, 138 : 15, 139 : 8,
# 140 : 7, 141 : 10, 142 : 14, 143 : 60, 144 : 19, 145 : 23, 146 : 2, 147 : 9, 148 : 0, 149 : 0,
# 150 : 0, 151 : 7, 152 : 5, 153 : 4, 154 : 3, 155 : 0, 156 : 9, 157 : 3, 158 : 9, 159 : 10,
# 160 : 28, 161 : 11, 162 : 7, 163 : 5, 164 : 3, 165 : 6, 166 : 5, 167 : 3, 168 : 6, 169 : 13,
# 170 : 7, 171 : 31, 172 : 11, 173 : 15, 174 : 9, 175 : 7, 176 : 7, 177 : 17, 178 : 15, 179 : 7,
# 180 : 6, 181 : 7, 182 : 11, 183 : 3, 184 : 7, 185 : 7, 186 : 17, 187 : 12, 188 : 13, 189 : 5,
# 190 : 15, 191 : 6, 192 : 11, 193 : 21, 194 : 3, 195 : 8, 196 : 6, 197 : 3, 198 : 5, 199 : 7,
# 合計 : 100

# %% [markdown]
# # 偏り

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] % 100
df
# Out:
#       seq_no
# 0         73
# 1         32
# 2         33
# 3         34
# 4         35
# ...      ...
# 1081       8
# 1082      75
# 1083      59
# 1084      52
# 1085      74
#
# [1086 rows x 1 columns]

# %%
df.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
